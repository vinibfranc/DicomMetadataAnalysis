# %% [markdown]
# <h1><center><font size="6">Visualizador de Images e Metadados DICOM</font></center></h1>
#
# <hr>
#
# <center><font size="4">Vinícius Bonetti Franceschi</font></center></h1>

# %% [markdown]
# # Intro
#
# ## Visão geral
#
# O conjunto de dados é projetado para permitir que diferentes métodos sejam testados para examinar as tendências nos dados de imagem de TC associados ao uso de contraste e idade do paciente. A idéia básica é identificar texturas de imagem, padrões estatísticos e características que se correlacionam fortemente com essas características e possivelmente construir ferramentas simples para classificar automaticamente essas imagens quando tiverem sido classificadas erroneamente (ou encontrar outliers que podem ser casos suspeitos, medições ruins ou máquinas mal calibradas).
#
# ## Dados
# O conjunto de dados consiste em 50 imagens de câncer de pulmão. Mais detalhes no relatório! <br> Link do dataset completo - https://wiki.cancerimagingarchive.net/display/Public/LIDC-IDRI

# %% [markdown]
# # Imports

# %%
IS_LOCAL = False
import numpy as np
import pandas as pd
from skimage.io import imread
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import pydicom as dicom
#import dicom
import os

PATH = "C:\\Users\\vinif\\Desktop\\LIDC-IDRI\\"
print(os.listdir(PATH))
# Out:
# ['.ipynb_checkpoints', 'dataset', 'LIDC-IDRI-0001', 'LIDC-IDRI-0002', 'LIDC-IDRI-0003', 'LIDC-IDRI-0004', 'LIDC-IDRI-0005', 'LIDC-IDRI-0006', 'LIDC-IDRI-0007', 'LIDC-IDRI-0008', 'LIDC-IDRI-0009', 'LIDC-IDRI-0010', 'LIDC-IDRI-0011', 'LIDC-IDRI-0012', 'LIDC-IDRI-0013', 'LIDC-IDRI-0014', 'LIDC-IDRI-0015', 'LIDC-IDRI-0016', 'LIDC-IDRI-0017', 'LIDC-IDRI-0018', 'LIDC-IDRI-0019', 'LIDC-IDRI-0020', 'LIDC-IDRI-0021', 'LIDC-IDRI-0022', 'LIDC-IDRI-0023', 'LIDC-IDRI-0024', 'LIDC-IDRI-0025', 'LIDC-IDRI-0026', 'LIDC-IDRI-0027', 'LIDC-IDRI-0028', 'LIDC-IDRI-0029', 'LIDC-IDRI-0030', 'LIDC-IDRI-0031', 'LIDC-IDRI-0032', 'LIDC-IDRI-0033', 'LIDC-IDRI-0034', 'LIDC-IDRI-0035', 'LIDC-IDRI-0036', 'LIDC-IDRI-0037', 'LIDC-IDRI-0038', 'LIDC-IDRI-0039', 'LIDC-IDRI-0040', 'LIDC-IDRI-0041', 'LIDC-IDRI-0042', 'LIDC-IDRI-0043', 'LIDC-IDRI-0044', 'LIDC-IDRI-0045', 'LIDC-IDRI-0046', 'LIDC-IDRI-0047', 'LIDC-IDRI-0048', 'LIDC-IDRI-0049', 'LIDC-IDRI-0050', 'LIDC-IDRI-0051', 'LIDC-IDRI-0052', 'LIDC-IDRI-0053', 'LIDC-IDRI-0054', 'LIDC-IDRI-0055', 'LIDC-IDRI-0056', 'LIDC-IDRI-0057', 'LIDC-IDRI-0058', 'LIDC-IDRI-0059', 'LIDC-IDRI-0060', 'LIDC-IDRI-0061', 'LIDC-IDRI-0062', 'LIDC-IDRI-0063', 'LIDC-IDRI-0064', 'LIDC-IDRI-0065', 'LIDC-IDRI-0066', 'LIDC-IDRI-0067', 'LIDC-IDRI-0068', 'LIDC-IDRI-0069', 'LIDC-IDRI-0070', 'LIDC-IDRI-0071', 'LIDC-IDRI-0072', 'LIDC-IDRI-0073', 'LIDC-IDRI-0074', 'LIDC-IDRI-0075', 'LIDC-IDRI-0076', 'LIDC-IDRI-0077', 'LIDC-IDRI-0078', 'LIDC-IDRI-0079', 'LIDC-IDRI-0080', 'LIDC-IDRI-0081', 'LIDC-IDRI-0082', 'LIDC-IDRI-0083', 'LIDC-IDRI-0084', 'LIDC-IDRI-0085', 'LIDC-IDRI-0086', 'LIDC-IDRI-0087', 'LIDC-IDRI-0088', 'LIDC-IDRI-0089', 'LIDC-IDRI-0090', 'LIDC-IDRI-0091', 'LIDC-IDRI-0092', 'LIDC-IDRI-0093', 'LIDC-IDRI-0094', 'LIDC-IDRI-0095', 'LIDC-IDRI-0096', 'LIDC-IDRI-0097', 'LIDC-IDRI-0098', 'LIDC-IDRI-0099', 'LIDC-IDRI-0100', 'LIDC-IDRI-0101', 'LIDC-IDRI-0102', 'LIDC-IDRI-0103', 'LIDC-IDRI-0104', 'LIDC-IDRI-0105', 'LIDC-IDRI-0106', 'LIDC-IDRI-0107', 'LIDC-IDRI-0108', 'LIDC-IDRI-0109', 'LIDC-IDRI-0110', 'LIDC-IDRI-0111', 'LIDC-IDRI-0112', 'LIDC-IDRI-0113', 'LIDC-IDRI-0114', 'LIDC-IDRI-0115', 'LIDC-IDRI-0116', 'LIDC-IDRI-0117', 'LIDC-IDRI-0118', 'LIDC-IDRI-0119', 'LIDC-IDRI-0120', 'LIDC-IDRI-0121', 'LIDC-IDRI-0122', 'LIDC-IDRI-0123', 'LIDC-IDRI-0124', 'LIDC-IDRI-0125', 'LIDC-IDRI-0126', 'LIDC-IDRI-0127', 'LIDC-IDRI-0128', 'LIDC-IDRI-0129', 'LIDC-IDRI-0130', 'LIDC-IDRI-0131', 'LIDC-IDRI-0132', 'LIDC-IDRI-0133', 'LIDC-IDRI-0134', 'LIDC-IDRI-0135', 'LIDC-IDRI-0136', 'LIDC-IDRI-0137', 'LIDC-IDRI-0138', 'LIDC-IDRI-0139', 'LIDC-IDRI-0140', 'LIDC-IDRI-0141', 'LIDC-IDRI-0142', 'LIDC-IDRI-0143', 'LIDC-IDRI-0144', 'LIDC-IDRI-0145', 'LIDC-IDRI-0146', 'LIDC-IDRI-0147', 'LIDC-IDRI-0148', 'LIDC-IDRI-0149', 'LIDC-IDRI-0150', 'LIDC-IDRI-0151', 'LIDC-IDRI-0152', 'LIDC-IDRI-0153', 'LIDC-IDRI-0154', 'LIDC-IDRI-0155', 'LIDC-IDRI-0156', 'LIDC-IDRI-0157', 'LIDC-IDRI-0158', 'LIDC-IDRI-0159', 'LIDC-IDRI-0160', 'LIDC-IDRI-0161', 'LIDC-IDRI-0162', 'LIDC-IDRI-0163', 'LIDC-IDRI-0164', 'LIDC-IDRI-0165', 'LIDC-IDRI-0166', 'LIDC-IDRI-0167', 'LIDC-IDRI-0168', 'LIDC-IDRI-0169', 'LIDC-IDRI-0170', 'LIDC-IDRI-0171', 'LIDC-IDRI-0172', 'LIDC-IDRI-0173', 'LIDC-IDRI-0174', 'LIDC-IDRI-0175', 'LIDC-IDRI-0176', 'LIDC-IDRI-0177', 'LIDC-IDRI-0178', 'LIDC-IDRI-0179', 'LIDC-IDRI-0180', 'LIDC-IDRI-0181', 'LIDC-IDRI-0182', 'LIDC-IDRI-0183', 'LIDC-IDRI-0184', 'LIDC-IDRI-0185', 'LIDC-IDRI-0186', 'LIDC-IDRI-0187', 'LIDC-IDRI-0188', 'LIDC-IDRI-0189', 'LIDC-IDRI-0190', 'LIDC-IDRI-0191', 'LIDC-IDRI-0192', 'LIDC-IDRI-0193', 'LIDC-IDRI-0194', 'LIDC-IDRI-0195', 'LIDC-IDRI-0196', 'LIDC-IDRI-0197', 'LIDC-IDRI-0198', 'LIDC-IDRI-0199', 'LIDC-IDRI-0200', 'LIDC-IDRI-0201', 'LIDC-IDRI-0202', 'LIDC-IDRI-0203', 'LIDC-IDRI-0204', 'LIDC-IDRI-0205', 'LIDC-IDRI-0206', 'LIDC-IDRI-0207', 'LIDC-IDRI-0208', 'LIDC-IDRI-0209', 'LIDC-IDRI-0210', 'LIDC-IDRI-0211', 'LIDC-IDRI-0212', 'LIDC-IDRI-0213', 'LIDC-IDRI-0214', 'LIDC-IDRI-0215', 'LIDC-IDRI-0216', 'LIDC-IDRI-0217', 'LIDC-IDRI-0218', 'LIDC-IDRI-0219', 'LIDC-IDRI-0220', 'LIDC- ...

# %% [markdown]
# ## Extração automática de imagens do dataset
#
# Foi escolhido o corte transversal de CT representado na imagem 40 de cada um dos 50 primeiros pacientes

# %%
from shutil import copyfile

cont = 0
IMAGES = "C:\\Users\\vinif\\Desktop\\LIDC-IDRI"
for root, dirs, files in os.walk(IMAGES):
    if(os.path.exists(root+"\\"+'000040.dcm')):
        copyfile(root+"\\"+'000040.dcm', IMAGES+"\\dataset\\"+str(root.split("\\", 6)[5])+".dcm")
        cont+=1
        if(cont >= 50):
            break

# %% [markdown]
# # Leitura dos dados
#
#
# ## Leitura dos metadados
#
# Realizando a leitura dos metadados presentes no arquivo overview_lidc.csv

# %%
data_df = pd.read_csv(PATH+"/overview_lidc.csv")

# %%
print("CT Medical images -  rows:",data_df.shape[0]," columns:", data_df.shape[1])
# Out:
# CT Medical images -  rows: 1398  columns: 11

# %%
data_df.head()
# Out:
#   Collection      Patient Id  Study Date Study Description Modality  \
# 0  LIDC-IDRI  LIDC-IDRI-0001  01/01/2000               NaN       CT
# 1  LIDC-IDRI  LIDC-IDRI-0001  01/01/2000               NaN       DX
# 2  LIDC-IDRI  LIDC-IDRI-0002  01/01/2000               NaN       CT
# 3  LIDC-IDRI  LIDC-IDRI-0002  01/01/2000               NaN       DX
# 4  LIDC-IDRI  LIDC-IDRI-0003  01/01/2000               NaN       CT
#
#   Series Description        Manufacturer         Manufacturer Model  \
# 0                NaN  GE MEDICAL SYSTEMS            LightSpeed Plus
# 1                NaN  GE MEDICAL SYSTEMS    Revolution XQi ADS_28.2
# 2                NaN  GE MEDICAL SYSTEMS               LightSpeed16
# 3                NaN  GE MEDICAL SYSTEMS  Revolution XRd ADS_27.5.4
# 4                NaN  GE MEDICAL SYSTEMS               LightSpeed16
#
#                              Software Version  \
# 0                  LightSpeedApps2.4.2_H2.4M5
# 1    Ads Application Package VERSION ADS_28.2
# 2                                    06MW03.5
# 3  Ads Application Package VERSION ADS_27.5.4
# 4                                    06MW03.5
#
#                                           Series UID  Unnamed: 10
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636...          NaN
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818...          NaN
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.619372068417...          NaN
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.493562949900...          NaN
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.170706757615...          NaN

# %% [markdown]
# ## Lendo dados DICOM

# %%
print("Number of DICOM files:", len(os.listdir(PATH+"dataset")))
# Out:
# Number of DICOM files: 50

# %% [markdown]
# ### Processando dados DICOM
#
# Processando os arquivos DICOM com base no arquivo csv de metadados anteriormente lido

# %%
def process_data(path):
    dicom_data = []
    for filepath in glob(PATH+path):
        dicom_features = dicom.read_file(filepath)
        dicom_data.append({'path': filepath, 
                     'ID':dicom_features.PatientID,
                     'Modality':dicom_features.Modality,
                     'Manufacturer': dicom_features.Manufacturer})
    result = pd.DataFrame(dicom_data)
    result.head()
    return result

# %%
dicom_data = process_data('dataset/*.dcm')

# %% [markdown]
# ### Checando dados DICOM

# %%
dicom_data.head(10)
# Out:
#                ID        Manufacturer Modality  \
# 0  LIDC-IDRI-0001  GE MEDICAL SYSTEMS       CT
# 1  LIDC-IDRI-0002  GE MEDICAL SYSTEMS       CT
# 2  LIDC-IDRI-0003  GE MEDICAL SYSTEMS       CT
# 3  LIDC-IDRI-0004  GE MEDICAL SYSTEMS       CT
# 4  LIDC-IDRI-0005  GE MEDICAL SYSTEMS       CT
# 5  LIDC-IDRI-0006  GE MEDICAL SYSTEMS       CT
# 6  LIDC-IDRI-0007  GE MEDICAL SYSTEMS       CT
# 7  LIDC-IDRI-0008  GE MEDICAL SYSTEMS       CT
# 8  LIDC-IDRI-0009  GE MEDICAL SYSTEMS       CT
# 9  LIDC-IDRI-0010  GE MEDICAL SYSTEMS       CT
#
#                                                 path
# 0  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 1  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 2  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 3  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 4  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 5  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 6  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 7  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 8  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 9  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...

# %% [markdown]
# # Explorando dados

# %% [markdown]
# ## Verificando consistência entre csv e imagens
#
# Comparando as ocorrências de determinadas características dentro do conjunto de dados

# %%
def countplot_comparison(feature):
    fig, (ax1, ax3) = plt.subplots(1,2, figsize = (16, 4), squeeze=True)
    s1 = sns.countplot(data_df[feature], ax=ax1)
    s1.set_title("Overview data")
    s3 = sns.countplot(dicom_data[feature], ax=ax3)
    s3.set_title("Dicom files data")
    plt.show()

# %%
# Mostra a distribuição de modalidade de imagens no dataset (cerca de 1000 são de CT e 200 de DX por exemplo)
# Todas as 50 imagens escolhidas são de CT

countplot_comparison('Modality')

# %%
# Todas as 50 imagens escolhidas são do fornecedor GE MEDICAL SYSTEMS

countplot_comparison('Manufacturer')

# %% [markdown]
# ## Mostrando imagens DICOM e metadados iniciais

# %%
def show_images(data):
    img_data = list(data[:50].T.to_dict().values())
    f, ax = plt.subplots(10,5, figsize=(16, 20))
    for i,data_row in enumerate(img_data):
        data_row_img = dicom.read_file(data_row['path'])
        
        modality = data_row_img.Modality
        patient = data_row_img.PatientID
        manufacturer = data_row_img.Manufacturer
        
        ax[i//5, i%5].imshow(data_row_img.pixel_array, cmap=plt.cm.bone) 
        ax[i//5, i%5].axis('off')
        ax[i//5, i%5].set_title('Patient: {}\nModality: {}\n{}'.format(patient, modality, manufacturer))
        plt.subplots_adjust(hspace=0.8, wspace=0)
    plt.show()

# %%
show_images(dicom_data)

# %% [markdown]
# ### Mais características presentes em arquivos DICOM
#
# Um arquivo DICOM contém muito mais informações do que a imagem que representamos. Vamos dar uma olhada, para um dos arquivos DICOM, esta informação. Vamos ler apenas o primeiro arquivo dicom e mostrar esta informação.
#
# O código abaixo mostra as cerca de 90 características presentes em um arquivo DICOM que podem ser extraídas.

# %%
dicom_file_path = list(dicom_data[:1].T.to_dict().values())[0]['path']
dicom_file_dataset = dicom.read_file(dicom_file_path)
dicom_file_dataset
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.300552808835706340325740268743
# (0008, 0020) Study Date                          DA: '20000101'
# (0008, 0021) Series Date                         DA: '20000101'
# (0008, 0022) Acquisition Date                    DA: '20000101'
# (0008, 0023) Content Date                        DA: '20000101'
# (0008, 0024) Overlay Date                        DA: '20000101'
# (0008, 0025) Curve Date                          DA: '20000101'
# (0008, 002a) Acquisition DateTime                DT: '20000101'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0032) Acquisition Time                    TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '2819497684894126'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed Plus'
# (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.281105016513143058382674334957
# (0010, 0010) Patient's Name                      PN: ''
# (0010, 0020) Patient ID                          LO: 'LIDC-IDRI-0001'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 21d0) Last Menstrual Date                 DA: '20000101'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'DCM:113100/113105/113107/113108/113109/113111'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'LIDC-IDRI'
# (0013, 1013) Private tag data                    LO: '62796001'
# (0018, 0010) Contrast/Bolus Agent                LO: 'IV'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: "2.500000"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0090) Data Collection Diameter            DS: "500.000000"
# (0018, 1020) Software Version(s)                 LO: 'LightSpeedApps2.4.2_H2.4M5'
# (0018, 1100) Reconstruction Diameter             DS: "360.000000"
# (0018, 1110) Distance Source to Detector         DS: "949.075012"
# (0018, 1111) Distance Source to Patient          DS: "541.000000"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.000000"
# (0018, 1130) Table Height                        DS: "144.399994"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "570"
# (0018, 1151) X-Ray Tube Current                  IS: "400"
# (0018, 1152) Exposure                            IS: "4684"
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: "48000"
# (0018, 1190) Focal Spot(s)                       DS: "1.200000"
# (0018, 1210) Convolution Kernel                  SH: 'STANDARD'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.298806137288633453246975630178
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636438705059720603192
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "3000566"
# (0020, 0013) Instance Number                     IS: "69"
# (0020, 0032) Image Position (Patient)            DS: ['-166.000000', '-171.699997', '-180.000000']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.229925374658226729607867499499
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: "-180.000000"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.703125', '0.703125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: "-600"
# (0028, 1051) Window Width                        DS: "1600"
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0038, 0020) Admitting Date                      DA: '20000101'
# (0040, 0002) Scheduled Procedure Step Start Date DA: '20000101'
# (0040, 0004) Scheduled Procedure Step End Date   DA: '20000101'
# (0040, 0244) Performed Procedure Step Start Date DA: '20000101'
# (0040, 2016) Placer Order Number / Imaging Servi LO: ''
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (0040, a075) Verifying Observer Name             PN: 'Removed by CTP'
# (0040, a123) Person Name                         PN: 'Removed by CTP'
# (0040, a124) UID                                 UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.134679823151727173869649485663
# (0070, 0084) Content Creator's Name              PN: ''
# (0088, 0140) Storage Media File-set UID          UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.119692798703141253938768002161
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes

# %% [markdown]
# ### Escolha das características a serem analisadas
#
# Foram escolhidas as seguintes características, pois me pareceram relavantes para a análise das imagens:
#
# * ImageType
# * Contrast/Bolus Agent
# * Body Part Examined
# * Exposure Time
# * Filter Type
# * Convolution Kernel
# * Slice Location

# %%
def process_new_features(dicom_data, path):
    
    dicom_data = []
    for filepath in glob(PATH+path):
        data_row_img = dicom.read_file(filepath)
        dicom_data.append({'path': filepath, 
                     'ID':data_row_img.PatientID,
                     'Modality': data_row_img.Modality,
                     'BodyPart': data_row_img.BodyPartExamined,
                     'ConvKernel': data_row_img.ConvolutionKernel,
                     'SliceLocation': data_row_img.SliceLocation,
                     'Filter': data_row_img.FilterType,
                     'Exposure': data_row_img.ExposureTime,
                     })
    result = pd.DataFrame(dicom_data)
    result.head()
    return result

# %%
dicom_new_data = process_new_features(dicom_data, 'dataset/*.dcm')

# %%
dicom_new_data.head(10)
# Out:
#   BodyPart ConvKernel  Exposure       Filter              ID Modality  \
# 0    CHEST   STANDARD       570  BODY FILTER  LIDC-IDRI-0001       CT
# 1    CHEST   STANDARD       478  BODY FILTER  LIDC-IDRI-0002       CT
# 2    CHEST   STANDARD      1160  BODY FILTER  LIDC-IDRI-0003       CT
# 3    CHEST   STANDARD       690  BODY FILTER  LIDC-IDRI-0004       CT
# 4    CHEST   STANDARD       570  BODY FILTER  LIDC-IDRI-0005       CT
# 5    CHEST   STANDARD      1160  BODY FILTER  LIDC-IDRI-0006       CT
# 6    CHEST       LUNG       912  BODY FILTER  LIDC-IDRI-0007       CT
# 7    CHEST   STANDARD       912  BODY FILTER  LIDC-IDRI-0008       CT
# 8    CHEST   STANDARD       872  BODY FILTER  LIDC-IDRI-0009       CT
# 9    CHEST   STANDARD       500  BODY FILTER  LIDC-IDRI-0010       CT
#
#    SliceLocation                                               path
# 0    -180.000000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 1    -192.000000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 2    -196.500000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 3    -266.250000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 4    -180.044998  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 5    -171.500000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 6    -279.500000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 7    -185.720001  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 8    -171.250000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...
# 9    -276.250000  C:\Users\vinif\Desktop\LIDC-IDRI\dataset\LIDC-...

# %%
print("Patient ID: {}\nModality: {}\nImageType: {}\nContrast: {}\nBodyPartExamined: {}\nConvolutionKernel: {}\nSliceLocation: {}\nFilter: {}\nExposure: {}\n".format(
    dicom_file_dataset.PatientID,
    dicom_file_dataset.Modality,
    dicom_file_dataset.ImageType,
    dicom_file_dataset.ContrastBolusAgent,
    dicom_file_dataset.BodyPartExamined,
    dicom_file_dataset.ConvolutionKernel,
    dicom_file_dataset.SliceLocation,
    dicom_file_dataset.FilterType,
    dicom_file_dataset.ExposureTime,
    ))
# Out:
# Patient ID: LIDC-IDRI-0001
# Modality: CT
# ImageType: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# Contrast: IV
# BodyPartExamined: CHEST
# ConvolutionKernel: STANDARD
# SliceLocation: -180.000000
# Filter: BODY FILTER
# Exposure: 570

# %% [markdown]
# ## Plotando comparações entre novas características

# %%
def countplot_comparison_features(feature, size_x):
    fig, (ax1) = plt.subplots(1,1, figsize = (size_x, 4), squeeze=True)
    #fig, (ax1) = plt.plot(16, 4)
    s1 = sns.countplot(dicom_new_data[feature], ax=ax1)
    s1.set_title("Dicom files data")
    plt.show()

# %%
countplot_comparison_features(feature='BodyPart', size_x=10)

# %%
countplot_comparison_features(feature='ConvKernel', size_x=15)

# %%
countplot_comparison_features(feature='SliceLocation', size_x=30)

# %%
countplot_comparison_features(feature='Filter', size_x=10)

# %%
countplot_comparison_features(feature='Exposure', size_x=20)

# %% [markdown]
# ## Mostrando imagens com alguns metadados extraídos anteriormente

# %%
def show_dicom_images(data):
    img_data = list(data[:16].T.to_dict().values())
    f, ax = plt.subplots(4,4, figsize=(16,20))
    for i,data_row in enumerate(img_data):

        data_row_img = dicom.read_file(data_row['path'])
        modality = data_row_img.Modality
        slice_location = data_row_img.SliceLocation
        body_part = data_row_img.BodyPartExamined
        
        ax[i//4, i%4].imshow(data_row_img.pixel_array, cmap=plt.cm.bone) 
        ax[i//4, i%4].axis('off')
        ax[i//4, i%4].set_title('Patient: {}\nModality: {}\nSlice Location: {}\nBody Part: {}'.format(
         data_row['ID'], modality, slice_location, body_part))
    plt.show()

# %%
show_dicom_images(dicom_data)

# %% [markdown]
# # Referências
#
# [1] <a href="https://www.kaggle.com/kmader">Kevin Mader</a>,  <a href="https://www.kaggle.com/kmader/show-the-data-in-the-zip-file">Show the data in the Zip File</a>
# [2] <a href="https://www.kaggle.com/byrachonok">Vitaly Byrachonok</a>,  <a href="https://www.kaggle.com/byrachonok/study-ct-medical-images">Study CT Medical Images</a>
# [3] Python package for processing DICOM data, dicom-numpy, https://dicom-numpy.readthedocs.io
# [4] Viewing DICOM images in Python, https://pydicom.github.io/pydicom/stable/viewing_images.html
